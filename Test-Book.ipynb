# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt 

df = pd.read_csv("netflix_titles.csv")
#print(df.info())

#make a histogram of the years and which (tv or movie) was released more in what years?
min_year = df['release_year'].min()
min_year
max_year = df['release_year'].max()
max_year        #1925 - 2021
# Out:
# 2021

# %%
print(max_year)
# Out:
# 2021

# %%
df["release_year"].value_counts().sort_index(ascending=False).head(50)
# Out:
# 2021     592
# 2020     953
# 2019    1030
# 2018    1147
# 2017    1032
# 2016     902
# 2015     560
# 2014     352
# 2013     288
# 2012     237
# 2011     185
# 2010     194
# 2009     152
# 2008     136
# 2007      88
# 2006      96
# 2005      80
# 2004      64
# 2003      61
# 2002      51
# 2001      45
# 2000      37
# 1999      39
# 1998      36
# 1997      38
# 1996      24
# 1995      25
# 1994      22
# 1993      28
# 1992      23
# 1991      17
# 1990      22
# 1989      16
# 1988      18
# 1987       8
# 1986      13
# 1985      10
# 1984      12
# 1983      11
# 1982      17
# 1981      13
# 1980      11
# 1979      11
# 1978       7
# 1977       7
# 1976       9
# 1975       7
# 1974       7
# 1973      10
# 1972       5
# Name: release_year, dtype: int64

# %%
df["listed_in"].value_counts().head(50)
# Out:
# Dramas, International Movies                                         362
# Documentaries                                                        359
# Stand-Up Comedy                                                      334
# Comedies, Dramas, International Movies                               274
# Dramas, Independent Movies, International Movies                     252
# Kids' TV                                                             220
# Children & Family Movies                                             215
# Children & Family Movies, Comedies                                   201
# Documentaries, International Movies                                  186
# Dramas, International Movies, Romantic Movies                        180
# Comedies, International Movies                                       176
# Comedies, International Movies, Romantic Movies                      152
# Dramas                                                               138
# ...

# %%
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
trends_over_time = df.groupby('release_year').type.value_counts().unstack().fillna(0)

# %%
trends_over_time
# Out:
# type          Movie  TV Show
# release_year
# 1925            0.0      1.0
# 1942            2.0      0.0
# 1943            3.0      0.0
# 1944            3.0      0.0
# 1945            3.0      1.0
# ...             ...      ...
# 2017          767.0    265.0
# 2018          767.0    380.0
# 2019          633.0    397.0
# 2020          517.0    436.0
# 2021          277.0    315.0
#
# [74 rows x 2 columns]

# %%
df["country"].value_counts()
# Out:
# United States                             2818
# India                                      972
# United Kingdom                             419
# Japan                                      245
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: country, Length: 748, dtype: int64

# %%
# Similar to countries, split 'listed_in' into individual genres
genre_data = df['listed_in'].str.split(', ', expand=True).stack().reset_index(level=1, drop=True)

# Count genre occurrences by year
genre_trends = df.groupby('release_year')['listed_in'].value_counts().unstack().fillna(0)

# %%
genre_data
# Out:
# 0                  Documentaries
# 1         International TV Shows
# 1                      TV Dramas
# 1                   TV Mysteries
# 2                 Crime TV Shows
#                   ...
# 8805    Children & Family Movies
# 8805                    Comedies
# 8806                      Dramas
# 8806        International Movies
# 8806            Music & Musicals
# Length: 19323, dtype: object

# %%
docMask = df['listed_in'].str.contains("Documentaries")

# %%
# Out:
# show_id         869
# type            869
# title           869
# director        812
# cast            445
# country         794
# date_added      869
# release_year    869
# rating          869
# duration        869
# listed_in       869
# description     869
# dtype: int64
